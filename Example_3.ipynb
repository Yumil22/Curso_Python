# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

df = pd.read_csv(url, names=['sepal length', 'sepal width' , 'petal lenght', 'petal width', 'target'])

df_datos = pd.read_csv('Trainingset.csv', index_col = 0)

# %%
#preview
df_datos
# Out:
#     DateReceived               Website  URLCount  R1Time  CrawlIssues  \
# 632   10/18/2021         deerstags.com        17     140          100
# 621   10/18/2021       mgchemicals.com       194     500            0
# 703   10/26/2021          godogfun.com        30      90            0
# 223   11/16/2021            tourit.com        20     120            0
# 14           NaT        manicpanic.com        40     139           25
# ..           ...                   ...       ...     ...          ...
# 443    10/7/2021  purplepandastore.com        25     120            0
# 913    9/27/2021          logitech.com       151     139            0
# 791    9/27/2021          rollplay.com        20     139          100
# 29           NaT      aleradetails.com        40     139           25
# 744    9/27/2021            beliani.de        20     139            0
#
#      WebReviewDif  WebsitePriority  ErrorCount  R2Time  TeamLeadSBQ  ...  \
# ...

# %%
group = df_datos.groupby('Other?').groups
print(len(group))
print(len(df_datos))
#Son la misma cantidad de datos que de paginas Web, por lo que no existiria agrupacion alguna.
group = df_datos.groupby('Other?')
df_datos.groupby('IncorrectGuidance').groups
# Out:
# 2
# 132
# {False: [632, 621, 703, 223, 14, 15, 945, 778, 695, 972, 103, 20, 618, 0, 810, 944, 301, 11, 26, 47, 27, 170, 242, 994, 1075, 579, 7, 827, 516, 613, 106, 137, 823, 16, 232, 837, 18, 1082, 783, 652, 25, 1072, 17, 918, 577, 23, 1018, 679, 1014, 1064, 3, 39, 574, 2, 824, 624, 158, 803, 914, 30, 198, 127, 125, 161, 133, 24, 22, 86, 1080, 250, 325, 55, 708, 405, 28, 697, 9, 378, 673, 513, 546, 420, 73, 1062, 801, 19, 471, 8, 962, 583, 1076, 271, 874, 1030, 176, 531, 1074, 1078, 174, 980, ...], True: [542]}

# %%
print(df_datos.columns.size)
#Vemos que tenemos 41 columnas diferentes sin contar el id
df_datos.columns
# Out:
# 41
# 'DateReceived'

# %% [markdown]
# # Analisis de la base de datos
# Empezamos analisando que datos podríamos/deberíamos descartar dentro de la base de datos, esto lo haremos primero de una mnaera "visual" y depues aplicaremos un analisis PCA.
#
# El primer dato es un indice que realmente podemos descartar.
# Al momento de ver las paginas web, vemos que todas son diferentes por lo que no tiene una relevancia.
